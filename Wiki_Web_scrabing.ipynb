# %%
import requests, json
from lxml import etree
from bs4 import BeautifulSoup

def scraper(scientist):
    #Tested with University of Toronto, Chan Sui Ki, University of Santo Tomas, Far Eastern University,
    #University of Michigan and more...

    #Get the real page title through wikipedia eng api
    url = 'https://ta.wikipedia.org/w/api.php?action=query&format=json&list=search&srsearch=%s' % scientist

    req = requests.get(url)

    #Fetch the json data
    output = json.loads(req.text)
    #take the first matching result
    page_title = output['query']['search'][0]['title']
    page_id = output['query']['search'][0]['pageid']
    print('Found page with title "%s" and id %s' % (page_title,page_id))

    #Make the request for the page requested by the user
    result_url = 'https://ta.wikipedia.org/wiki?curid=%d' % page_id

    result_req = requests.get(result_url).text
    soup = BeautifulSoup(result_req,features='lxml')
    table = soup.find('table',class_='infobox vcard') or soup.find('table',class_='infobox biography vcard') or soup.find('table',class_='infobox')
     
    result = {}
    for row in table.find_all('tr')[1:]:
        
        if row.find('th'):
            result[row.find('th').text] = row.find('td').text
       
    print(result)
    
         
    return {key.strip():result[key].strip() for key in result}

    #Look for the college motto

# %%
scraper("ஐசாக்_நியூட்டன்")
# Out:
# Found page with title "ஐசாக் நியூட்டன்" and id 1511
# ...

# %%
def listform(Dict):
    list=[]
    if 'பிறப்பு' in Dict:
        list.append(Dict['பிறப்பு'])
    else:
        list.append("")
    
    if 'இறப்பு' in Dict:
        list.append(Dict['இறப்பு'])
    else:
        list.append("")
    
    if 'வாழிடம்' in Dict:
        list.append(Dict['வாழிடம்'])
    else:
        list.append("")

    if 'தேசியம்' in Dict:
        list.append(Dict['தேசியம்'])
    else:
        list.append("")

    if 'துறை' in Dict:
        list.append(Dict['துறை'])
    else:
        list.append("")
    
    if 'பணியிடங்கள்' in Dict:
        list.append(Dict['பணியிடங்கள்'])
    else:
        list.append("")
    
    if 'கல்வி கற்ற இடங்கள்' in Dict:
        list.append(Dict['கல்வி கற்ற இடங்கள்'])
    else:
        list.append("")

    if 'அறியப்படுவது' in Dict:
        list.append(Dict['அறியப்படுவது'])
    else:
        list.append("")
    return list

# %%
Scientists=[["பிலைசு_பாஸ்கல்","கூட்டும் இயந்திரம்"],["ஜான்_டால்ட்டன்","அணுக் கொள்கை"],["வோல்ட்டா","மின்கலம்"],["ஜான்_பாய்டு_டன்லப்","சைக்கிள் டயர்கள்"],
            ["ஐசாக்_நியூட்டன்","நியூட்டனின் ஈர்ப்பு விதி"],["அலெக்சாண்டர்_கிரகாம்_பெல்","தொலைபேசி கண்டுபிடிப்பு"],
            ["ருடோல்ப்_டீசல்","டீசல் எஞ்சின்"],["தாமசு_ஆல்வா_எடிசன்","மின் விளக்கு"],["நிக்கோலா_தெஸ்லா","மின் மோட்டார்"],
            ["வில்லியம்_ஸ்டர்ஜியன்","மின் காந்தம்"],["ஜான்_நேப்பியர்","மடக்கைகள்"],["மேரி_கார்ட்ரைட்","ஆற்றல் பெருக்கம்"],["ஜான்_வாக்கர்","தீப்பெட்டி"],["ஜேம்ஸ்_சாட்விக்","நியூட்ரான்"],
            ["இலூயி_பாசுச்சர்","பாஸ்டுரைசேசன்"],["திமீத்ரி_மெண்டெலீவ்","தனிம வரிசை அட்டவணை"],["யோகான்னசு_கூட்டன்பர்கு","பிரின்டிங் பிரஸ்"],["எர்ணஸ்ட்_ரதர்ஃபோர்டு","புரோட்டான்"],
            ["வில்லார்ட்_ஃபிராங்க்_லிப்பி","ரேடியோ கார்பன் வயது கணிப்பான்"],["மார்க்கோனி","ரேடியோ"],["ஜோசப்_வில்சன்_ஸ்வான்","மின்விளக்கு"],["ஆல்பர்ட்_ஐன்ஸ்டைன்","ரிலேட்டிவிட்டி தியரி"],["வால்டர்_ஹன்ட்","பாதுகாப்பு ஊசி"],["ஜான்_ஷெப்பர்ட்_பேரோன்","ATM"],["ஜேம்ஸ்_வாட்", "நீராவி இயந்திரம்"],["சாமுவெல்_மோர்சு","டெலகிராப் கோடு"],
            ["கலீலியோ_கலிலி","வெப்பநிலைமானி"],["மைக்கேல்_பரடே","மின் மாற்றி"],["சார்லசு_டார்வின்","பரிணாம வளர்ச்சிக் கொள்கை"],["நிக்கோலாஸ்_கோப்பர்னிக்கஸ்","சூரியமையக் கொள்கை"],
            ["ஆர்க்கிமிடீஸ்","ஆர்கிமிடிஸ் கொள்கை"],["ஜான்_கவுச்_ஆடம்சு","நிலாவின் நிரலியக்க வேறுபாடு"],["அந்தோனி_எவிசு","துடிவிண்மீன்கள்"],
            ["ஆர்த்தர்_எடிங்டன்","எடிங்டன் வரம்பு"],["மன்_மோகன்_சூரி","சூரி டிரான்ஸ்மிசன் என்ற உழவு இயந்திரத்தை இந்தியாவில் அறிமுகப்படுத்தியது"],
            ["இரெனே_பாவலோரோ" ,"இதயக் குழாய்க்கு மாற்றுவழி அமைக்கும் அறுவையைப்பற்றிய சிறந்த கல்வியாளரும் ஆவார்"],
            ["ஓலே_உரோமர்" ,"ஒளியின் வேகத்தை முதலில் அளந்து மதிப்பிட்டார்"],["கெரால்டு_டெனிசு_டைலர்" ,"கூக்கின் மும்மை வில்லையை உருவாக்கியது"],
            ["ஜியார்ஜ்_வான்_பியூயர்பக்" ,"தாலமிய வானியலை"],["ஆலன்_சாந்தேகு" ,"அண்டக் கட்டமைப்பியல்"],["உருடோல்ப்_மின்கோவ்சுகி","மீவிண்மீன் வெடிப்பு"],
            ["எய்னார்_எர்ட்சுபிரங்கு" ,"எர்ட்சுபிரங்கு-இரசல் விளக்கப்படம்"],["சேத்_பார்னசு_நிக்கல்சன்" ,"பசிபிக் வானியல் கழக வெளியீடு"],
            ["நார்மன்_இராபர்ட்_போகுசன் ", "சிறுகோள்"],["பிரெட்_இலாரன்சு_விப்பிள்" ,"வால்வெள்ளிகளின் உட்கூறுகள்"],["பெஞ்சமின்_ஆப்தார்ப்_கவுல்டு","வானியல் இதழ்"],
            ["பெர்சிவால்_உலோவெல்" ,"செவ்வாய்க் கால்வாய்கள்"],["மேக்சு_வுல்ஃப்" ,"வானொளிப்படவியல்"],["வால்டேர்_பாடே" ,"செருமானிய வானியலாளர்"],
            ["விக்தர்_நோர்" ,"கோரோனிசுவையும் மேலும் மூன்று சிறுகோள்களையும் கண்டுபிடித்தல்"],["நிக்கோலஸ்_ஓட்டோ" ,"உள் எரி பொறி"],
            ["டோரதி_ஓட்ச்கின்" ,"எக்சு-கதிர்"],["எட்வர்ட்_ஜென்னர்","பெரியம்மை தடுப்பு மருந்து"],["கர்ரெட்_மார்கன்", "போக்குவரத்து சிக்னல் மற்றும் நச்சுவாயு பாதுகாப்பு முகக் கவசம் கண்டுபிடிப்பாளர்"],
            ["சாமுவெல்_மோர்சு" , "மோர்ஸ் code"],
            ["ஜார்ஜ்_காமாவ்" ,"அண்ட நுண்ணலைப் பின்னணிக் கதிர்வீச்சு"] ,["எர்பர்ட்டு_என்றி_டவ்" , "டவ் கெமிக்கல் கம்பெனி நிறுவனர்"],["வால்டர்_பிராட்டன்","திரிதடையம்"],["இராபர்ட்_காடர்ட்" , "முதலாவது திரவ எரிபொருள் ராக்கெட்டைக் கண்டுபிடித்தமை"],["டக்லஸ்_எங்கல்பர்ட்" , "சுட்டி மீயுரை சேர்ந்தியங்கல் மென்பொருள்"],
            ["ஜான்_கே","பறக்கும் நாடா"],["டென்னிஸ்_கபார்" , "ஹாலோகிராபி" ],["ஹம்பிரி_டேவி" ,"மின்னாற்பகுப்பு"], ["சாமுவேல்_கிராம்டன்" ,"மியுனூற்றற்பொறி"],["எட்மண்டு_ஏலி","ஏலியின் வால்வெள்ளியின் சுற்றுப்பாதை"],["ஹெர்த்தா_அயர்டன்" , "மின்சார வட்ட வில்"],["அலன்_டூரிங்" , "நிறுத்தல் பிரச்சினை டூரிங் இயந்திரம்"],["இவாஞ்சலிசிட்டா_தோரிச்செல்லி", "காற்றழுத்தமானி"],["டேவிட்_வாரன்" ,"விமான தரவு பதிவி"],["ருடோல்ப்_டீசல்", "டீசல் இயந்திரத்தின் கண்டுபிடிப்பாளர்"],["மரியா_மிட்செல்" , "அமெரிக்கப் பெண் தொழில்முறை வானியலாளர்"],["சார்லசு_மெசியர்" , "மெசியர் அட்டவணை"],["எட்வார்டு_எமர்சன்_பர்னார்டு" , "பர்னார்டு விண்மீன்"],["யோகான்னசு_எவெலியசு" , "நிலாக் நிலக்கிடப்பியல்"],["ஹென்ரிச்_ஒல்பெர்ஸ்" , "பிறர் முரண்படு மெய்ம்மை"],["விர்ஜீனியா_ஆப்கர்" , "அப்கார் எண்ணிக்கை"],["டெம்பிள்_கிராண்டின்" , "கால்நடைத் துறையின் ஆலோசகர்"],["பெட்டி_நெசுமித்_கிரகாம்" , "வெண்மையாக்கி நீர்மம் உருவாக்கம்"],["ஹெலன்_மர்ரே_பிரீ" , "நீரிழிவுக்கான சுய பரிசோதனை அமைப்பு"],["கியூலியானா_காவக்லியேரி_தெசாரோ","தீத்தடுப்புத் துகில்கள்"],["ரோசலின்_யாலோ" , "கதிரியக்கத் தடுப்பாற்று வினைக்கணிப்பு"], ["பால்_ஹெரௌல்ட்" , "அலுமினியம் மின்னாற்பகுப்பு"],["மத்தாயூ_ஆர்ஃபிலா", "நச்சியலைக் கண்டுபிடித்தவர்"],["சார்ல்ஸ்_பாபேஜ்" ,"கணினி"] ,["மரியோன்_தொனோவன்" ,"முதல் நீர்க்காப்பு"],["எலைஜா_மெக்காய்" , "தானியங்கி உயவிடுவான்"],["ரைட்_சகோதரர்கள்","விமானம்"],["ஹென்றி_ஃபோர்ட்","ஆகாய கப்பல்"],["எட்வர்ட்_டெல்லர்","ஹைட்ரஜன் குண்டு"],["யோன்_அரிசன்" , "கடற் காலமானி"]]

# %%
Science=[]
for scientist in Scientists:
    list=[]
    list.append(scientist[0])
    
    details=scraper(scientist[0]) 
     
    list.extend(listform(details))
    list.append(scientist[-1])
    print(list)
    Science.append(list)
# Out:
# Found page with title "பிலைசு பாஸ்கல்" and id 92803
# {'முழுப்\xa0பெயர்': 'பிலைசு பாஸ்கல்', 'பிறப்பு': 'சூன் 19, 1623(1623-06-19)', 'இறப்பு': 'ஆகத்து 19, 1662(1662-08-19) (அகவை\xa039)', 'சிந்தனைமரபு(கள்)': 'Continental Philosophy, precursor to existentialism', 'முக்கியஆர்வங்கள்': 'மெய்யியல், கணிதம்', 'குறிப்பிடத்தக்கஎண்ணக்கருக்கள்': "Pascal's Wager"}
# ['பிலைசு_பாஸ்கல்', 'சூன் 19, 1623(1623-06-19)', 'ஆகத்து 19, 1662(1662-08-19) (அகவை\xa039)', '', '', '', '', '', '', 'கூட்டும் இயந்திரம்']
# Found page with title "ஜான் டால்ட்டன்" and id 350685
# ...

# %%
len(Science)
# Out:
# 90

# %%
import pandas as pd


df = pd.DataFrame(Science)
df.columns=["கண்டுபிடிப்பாளர்",'பிறப்பு','இறப்பு','வாழிடம்','தேசியம்','துறை','பணியிடங்கள்','கல்வி கற்ற இடங்கள்','அறியப்படுவது',"கண்டுபிடிப்பு"]

# %%
df
# Out:
#       கண்டுபிடிப்பாளர்                                            பிறப்பு  \
# 0       பிலைசு_பாஸ்கல்                          சூன் 19, 1623(1623-06-19)
# 1       ஜான்_டால்ட்டன்  செப்டம்பர் 6, 1766(1766-09-06) Eaglesfield, Cu...
# 2             வோல்ட்டா                               18 பெப்ரவரி 1745Como
# 3   ஜான்_பாய்டு_டன்லப்  பெப்ரவரி 5, 1840(1840-02-05)Dreghorn, North Ay...
# 4      ஐசாக்_நியூட்டன்  25 டிசம்பர் 1642[கிநா: சனவரி 4, 1643(1643-01-0...
# ..                 ...                                                ...
# 85      எலைஜா_மெக்காய்  எலைஜா ஜெ. மெக்காய்மே 2, 1844கோல்செஸ்டர், ஆன்டா...
# 86     ரைட்_சகோதரர்கள்  ஓர்வில் ரைட்: ஆகத்து 19, 1871(1871-08-19)\n, ட...
# 87      ஹென்றி_ஃபோர்ட்  சூலை 30, 1863(1863-07-30)கிரீன்ஃபீல்ட் நகர், ட...
# 88    எட்வர்ட்_டெல்லர்  சனவரி 15, 1908(1908-01-15)Budapest, ஆத்திரியா-...
# 89         யோன்_அரிசன்  மார்ச்சு 24, 1693(1693-03-24) யோக்சயரின் வேக்ஃ...
#
#                                                இறப்பு             வாழிடம்  \
# ...

# %%
df.to_csv('Scientists_before_processing.csv',sep=',', index=False)
